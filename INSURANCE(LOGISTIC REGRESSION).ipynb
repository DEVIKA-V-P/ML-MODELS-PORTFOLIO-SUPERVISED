# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ins=pd.read_csv('8.logiistic_regression_data.csv')
ins.head()
# Out:
#    age  brought_insurance
# 0   21                  0
# 1   25                  0
# 2   47                  1
# 3   52                  0
# 4   46                  1

# %%
ins.isna().sum()
# Out:
# age                  0
# brought_insurance    0
# dtype: int64

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                27 non-null     int64
#  1   brought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 564.0 bytes

# %%
sns.boxplot(ins)
# Out:
# <Axes: >

# %%
ins.shape
# Out:
# (27, 2)

# %%
x=ins[['age']]

# %%
y=ins['brought_insurance']

# %%
x.shape
# Out:
# (27, 1)

# %%
y.shape
# Out:
# (27,)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_train.shape
# Out:
# (21, 1)

# %%
y_train.shape
# Out:
# (21,)

# %%
x_test.shape
# Out:
# (6, 1)

# %%
y_test.shape
# Out:
# (6,)

# %%
ypred=model.predict(x_test)
ypred
# Out:
# array([1, 0, 0, 1, 1, 0], dtype=int64)

# %%
data=pd.DataFrame({'x':x_test['age'],'actual':y_test,'predicted':ypred})
data
# Out:
#      x  actual  predicted
# 17  58       1          1
# 14  28       0          0
# 18  19       0          0
# 3   52       0          1
# 23  45       1          1
# 10  18       0          0

# %%
model.score(x_test,y_test)
# Out:
# 0.8333333333333334

# %%
model.score(x_train,y_train)
# to check the accuracy in training data
# Out:
# 0.9047619047619048

# %%
model.predict_proba(x_test) # is a method used in classification models in Machine Learning to get probability scores instead of just class labels.
# probabilty score of 0and 1
# Out:
# array([[0.04795873, 0.95204127],
#        [0.80051103, 0.19948897],
#        [0.93719278, 0.06280722],
#        [0.10786705, 0.89213295],
#        [0.2513851 , 0.7486149 ],
#        [0.94525374, 0.05474626]])

# %%
new=model.predict([[8]])
new
# Out:
# array([0], dtype=int64)

# %%
age_1=model.predict([[90]])
age_1
# Out:
# array([1], dtype=int64)

# %%
 plt.scatter(x, y); plt.plot(x, model.predict_proba(x)[:, 1])
# x:input feature y:target values(0,1)
#predict_proba:predict probability for each class
# select only one class[0.8,0.2]-->0.8 
#plt.plot(x, model.predict_proba(x)[:, 1]) the line is the logistic regression best -fit(sigmoid)curve
