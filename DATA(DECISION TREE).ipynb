# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"D:\exel\17.DT_data.csv")
data.head()
# Out:
#       a1    a2      a3 Outcome
# 0   True   Hot    High      No
# 1   True   Hot    High      No
# 2  False   Hot    High     Yes
# 3  False  Cool  Normal     Yes
# 4  False  Cool  Normal     Yes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   a1       10 non-null     bool
#  1   a2       10 non-null     object
#  2   a3       10 non-null     object
#  3   Outcome  10 non-null     object
# dtypes: bool(1), object(3)
# memory usage: 382.0+ bytes

# %%
from sklearn.preprocessing import LabelEncoder

# %%
a=LabelEncoder()

# %%
b=LabelEncoder()

# %%
c=LabelEncoder()

# %%
data['a1']=a.fit_transform(data['a1'])

# %%
data['a2']=b.fit_transform(data['a2'])

# %%
data['a3']=c.fit_transform(data['a3'])

# %%
print('a1:',a.classes_)
print('a2:',b.classes_)
print('a3:',c.classes_)
# Out:
# a1: [False  True]
# a2: ['Cool' 'Hot']
# a3: ['High' 'Normal']

# %%
data
# Out:
#    a1  a2  a3 Outcome
# 0   1   1   0      No
# 1   1   1   0      No
# 2   0   1   0     Yes
# 3   0   0   1     Yes
# 4   0   0   1     Yes
# 5   1   0   0      No
# 6   1   1   0      No
# 7   1   1   1     Yes
# 8   0   0   1     Yes
# 9   0   0   0     Yes

# %%
x=data.iloc[:,:-1]
x
# Out:
#    a1  a2  a3
# 0   1   1   0
# 1   1   1   0
# 2   0   1   0
# 3   0   0   1
# 4   0   0   1
# 5   1   0   0
# 6   1   1   0
# 7   1   1   1
# 8   0   0   1
# 9   0   0   0

# %%
y=data.iloc[:,-1]
y
# Out:
# 0     No
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# 5     No
# 6     No
# 7    Yes
# 8    Yes
# 9    Yes
# Name: Outcome, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion='entropy')
model.fit(x,y)
y_pred=model.predict(x)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       1.00      1.00      1.00         4
#          Yes       1.00      1.00      1.00         6
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %%
from sklearn import tree

# %%
tree.plot_tree(model)
plt.show()

# %%
tree.plot_tree(model,filled=True,feature_names=['a1','a2','a3'])
plt.show()

# %%
# entrpy<0.5 left,# entropy
# false entropy yes
# high 
#entropy

# %%
from sklearn import tree
import matplotlib.pyplot as plt

tree.plot_tree(
    model,
    filled=True,
    feature_names=['a1', 'a2', 'a3'],
    class_names=['False', 'True']   # MUST match model.classes_
)

plt.show()
